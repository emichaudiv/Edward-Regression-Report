# %% [markdown]
# # Bathrooms for far more

# %% [markdown]
# ### The value of a Property tends to rise and fall overtime, but what makes a property consistantly high? Is it the area of land, the amount of bed rooms, or the amount of bathrooms? I wanted to find out if these were really the causes for higher prices.

# %% [markdown]
# ### Starting off we add important libraries and visualizations

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from env import user, password, host
import warnings
warnings.filterwarnings('ignore')

from acquire import zillow
from prepare import df

# %% [markdown]
# ## Is it because of the amount of bathrooms a property has?

# %%
from acquire import bathroomtax

# %%
bathroomtax(df)

# %% [markdown]
# ## Until you reach 4 bathrooms, bathrooms barely increase property value, but once you reach 10, it seems to take up most of the value.

# %% [markdown]
# # Could it be the amount of bed rooms?

# %%
from acquire import bedroomstax

# %%
bedroomstax(df)

# %% [markdown]
# ## Same as the bathrooms, it doesn't have alot of contribution until you have a large amount of rooms
# ### NOTE: This is taken from a small sample (1000 properties) in order to be able complete this project in a timely matter and could explain the sudden dip at 7 rooms.

# %% [markdown]
# # Is there any correlation between the two?

# %%
from acquire import bedbathsq

# %%
bedbathsq(df)

# %% [markdown]
# ## There is some correlation, especially at around the 6 bathroom/bedroom mark and it is higher, but there is definately more at 8 and possibly more.

# %% [markdown]
# # In Conclusion, there isn't any decisive evidence on whenever have more bed rooms and/or bathrooms  will make property value greatly increase (unless it does have many more rooms). Had I have more time, I would have explored more with the square foot of a property to see if there was any information on that.
